# %%
import sys
sys.path.append('/Users/chris/workspace/botocore')

import boto3

session = boto3.Session(profile_name='dev-admin', region_name='us-east-1')
client = session.client('mturk')

# import botocore.session
# import botocore.auth
# session = botocore.session.get_session()
# session.create_client('mturk')

# %%
client.get_account_balance()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/chris/workspace/botocore/botocore/model.py in get_shape_by_name(self, shape_name, member_traits)
#     452         try:
# --> 453             shape_model = self._shape_map[shape_name]
#     454         except KeyError:
#
# KeyError: 'EventSourceConfiguration'
#
# During handling of the above exception, another exception occurred:
#
# NoShapeFoundError                         Traceback (most recent call last)
# <ipython-input-2-6a413783d91c> in <module>()
# ----> 1 client.get_account_balance()
#
# /Users/chris/workspace/botocore/botocore/client.py in _api_call(self, *args, **kwargs)
#     234                     "%s() only accepts keyword arguments." % py_operation_name)
#     235             # The "self" in this scope is referring to the BaseClient.
# --> 236             return self._make_api_call(operation_name, kwargs)
#     237
#     238         _api_call.__name__ = str(py_operation_name)
#
# /Users/chris/workspace/botocore/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     487         else:
#     488             http, parsed_response = self._endpoint.make_request(
# --> 489                 operation_model, request_dict)
#     490
#     491         self.meta.events.emit(
#
# /Users/chris/workspace/botocore/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     115         logger.debug("Making request for %s (verify_ssl=%s) with params: %s",
#     116                      operation_model, self.verify, request_dict)
# --> 117         return self._send_request(request_dict, operation_model)
#     118
#     119     def create_request(self, params, operation_model=None):
#
# /Users/chris/workspace/botocore/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     144             request, operation_model, attempts)
#     145         while self._needs_retry(attempts, operation_model,
# --> 146                                 success_response, exception):
#     147             attempts += 1
#     148             # If there is a stream associated with the request, we need
#
# /Users/chris/workspace/botocore/botocore/endpoint.py in _needs_retry(self, attempts, operation_model, response, caught_exception)
#     217             event_name, response=response, endpoint=self,
#     218             operation=operation_model, attempts=attempts,
# --> 219             caught_exception=caught_exception)
#     220         handler_response = first_non_none_response(responses)
#     221         if handler_response is None:
#
# /Users/chris/workspace/botocore/botocore/hooks.py in emit(self, event_name, **kwargs)
#     224                  handlers.
#     225         """
# --> 226         return self._emit(event_name, kwargs)
#     227
#     228     def emit_until_response(self, event_name, **kwargs):
#
# /Users/chris/workspace/botocore/botocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     207         for handler in handlers_to_call:
#     208             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 209             response = handler(**kwargs)
#     210             responses.append((handler, response))
#     211             if stop_on_response and response is not None:
#
# /Users/chris/workspace/botocore/botocore/retryhandler.py in __call__(self, attempts, response, caught_exception, **kwargs)
#     181
#     182         """
# --> 183         if self._checker(attempts, response, caught_exception):
#     184             result = self._action(attempts=attempts)
#     185             logger.debug("Retry needed, action of: %s", result)
#
# /Users/chris/workspace/botocore/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     248     def __call__(self, attempt_number, response, caught_exception):
#     249         should_retry = self._should_retry(attempt_number, response,
# --> 250                                           caught_exception)
#     251         if should_retry:
#     252             if attempt_number >= self._max_attempts:
#
# /Users/chris/workspace/botocore/botocore/retryhandler.py in _should_retry(self, attempt_number, response, caught_exception)
#     263                 attempt_number < self._max_attempts:
#     264             try:
# --> 265                 return self._checker(attempt_number, response, caught_exception)
#     266             except self._retryable_exceptions as e:
#     267                 logger.debug("retry needed, retryable exception caught: %s",
#
# /Users/chris/workspace/botocore/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     311         for checker in self._checkers:
#     312             checker_response = checker(attempt_number, response,
# --> 313                                        caught_exception)
#     314             if checker_response:
#     315                 return checker_response
#
# /Users/chris/workspace/botocore/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     220             return self._check_response(attempt_number, response)
#     221         elif caught_exception is not None:
# --> 222             return self._check_caught_exception(attempt_number, caught_exception)
#     223         else:
#     224             raise ValueError("Both response and caught_exception are None.")
#
# /Users/chris/workspace/botocore/botocore/retryhandler.py in _check_caught_exception(self, attempt_number, caught_exception)
#     353         # the MaxAttemptsDecorator is not interested in retrying the exception
#     354         # then this exception just propogates out past the retry code.
# --> 355         raise caught_exception
#
# /Users/chris/workspace/botocore/botocore/endpoint.py in _get_response(self, request, operation_model, attempts)
#     171             http_response = self.http_session.send(
#     172                 request, verify=self.verify,
# --> 173                 stream=operation_model.has_streaming_output,
#     174                 proxies=self.proxies, timeout=self.timeout)
#     175         except ConnectionError as e:
#
# /Users/chris/workspace/botocore/botocore/utils.py in __get__(self, obj, cls)
#     489             return self
#     490         else:
# --> 491             computed_value = self._fget(obj)
#     492             obj.__dict__[self._fget.__name__] = computed_value
#     493             return computed_value
#
# /Users/chris/workspace/botocore/botocore/model.py in has_streaming_output(self)
#     414     @CachedProperty
#     415     def has_streaming_output(self):
# --> 416         return self.get_streaming_output() is not None
#     417
#     418     def get_streaming_input(self):
#
# /Users/chris/workspace/botocore/botocore/model.py in get_streaming_output(self)
#     420
#     421     def get_streaming_output(self):
# --> 422         return self._get_streaming_body(self.output_shape)
#     423
#     424     def _get_streaming_body(self, shape):
#
# /Users/chris/workspace/botocore/botocore/utils.py in __get__(self, obj, cls)
#     489             return self
#     490         else:
# --> 491             computed_value = self._fget(obj)
#     492             obj.__dict__[self._fget.__name__] = computed_value
#     493             return computed_value
#
# /Users/chris/workspace/botocore/botocore/model.py in output_shape(self)
#     406             return None
#     407         return self._service_model.resolve_shape_ref(
# --> 408             self._operation_model['output'])
#     409
#     410     @CachedProperty
#
# /Users/chris/workspace/botocore/botocore/model.py in resolve_shape_ref(self, shape_ref)
#     240
#     241     def resolve_shape_ref(self, shape_ref):
# --> 242         return self._shape_resolver.resolve_shape_ref(shape_ref)
#     243
#     244     @instance_cache
#
# /Users/chris/workspace/botocore/botocore/model.py in resolve_shape_ref(self, shape_ref)
#     483                 raise InvalidShapeReferenceError(
#     484                     "Invalid model, missing shape reference: %s" % shape_ref)
# --> 485             return self.get_shape_by_name(shape_name, member_traits)
#     486
#     487
#
# /Users/chris/workspace/botocore/botocore/model.py in get_shape_by_name(self, shape_name, member_traits)
#     453             shape_model = self._shape_map[shape_name]
#     454         except KeyError:
# --> 455             raise NoShapeFoundError(shape_name)
#     456         try:
#     457             shape_cls = self.SHAPE_CLASSES.get(shape_model['type'], Shape)
#
# NoShapeFoundError: EventSourceConfiguration
